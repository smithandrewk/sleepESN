# %%
# activity
to_plot = pd.melt(df,id_vars=['label'],value_vars=['activity'])
plt.figure(figsize=(7.2,4.45))
ax = sns.kdeplot(data=to_plot,x='value',hue='label')
plt.xlim(-.25,.25)
# Out:
# (-0.25, 0.25)

# %%
# emg
to_plot = pd.melt(df,id_vars=['label'],value_vars=['emg'])
plt.figure(figsize=(7.2,4.45))
ax = sns.kdeplot(data=to_plot,x='value',hue='label')

# %%
to_plot = pd.melt(df.iloc[:,1:-2],id_vars=['label'])
plt.figure(figsize=(7.2,4.45))
ax = sns.lineplot(data=to_plot,x='variable',y='value',hue='label',ci=99.99)
ax.set(yscale='log')
# Out:
# [None]
